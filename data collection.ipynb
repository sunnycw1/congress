# %%
import os
from pathlib import Path
import requests
from bs4 import BeautifulSoup
import pandas as pd
pd.options.display.max_columns = None

# %% [markdown]
# # 1. Bills

# %% [markdown]
# files downloaded from
# http://congressionalbills.org/download.html. check can read into pandas:

# %%
bills80_92 = pd.read_csv('bills80-92.txt',sep='\t')
# Out:
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
bills93_114 = pd.read_csv('bills93-114.csv',sep=';',encoding='cp1252')

# %%
bills80_92.shape, bills93_114.shape
# Out:
# ((229317, 61), (294524, 48))

# %%
bills80_92.rename(columns={' ': 'Minor'}, inplace=True) # mis-named column
bills80_92.head()
# Out:
#       id   BillID  BillNum BillType  ByReq  Chamber  Commem  Cong  Cosponsr  \
# 0  38183  80-HR-1        1       HR    NaN        0     NaN    80       NaN
# 1  38184  80-HR-2        2       HR    NaN        0     NaN    80       NaN
# 2  38185  80-HR-3        3       HR    NaN        0     NaN    80       NaN
# 3  38186  80-HR-4        4       HR    NaN        0     NaN    80       NaN
# 4  38187  80-HR-5        5       HR    NaN        0     NaN    80       NaN
#
#    IntrDate  oldMajor  oldMinor  Major  Minor  Month  Mult  MultNo  PassH  \
# 0       NaN         1       107      1    107    NaN   0.0       1      1
# 1       NaN        16      1608     16   1608    NaN   0.0       1      0
# 2       NaN        16      1608     16   1608    NaN   0.0       1      0
# 3       NaN        12      1204     12   1204    NaN   0.0       1      1
# 4       NaN        16      1609     16   1608    NaN   0.0       1      0
#
# ...

# %%
bills93_114.head()
# Out:
#          BillID  BillNum BillType  Chamber  Cong  Cosponsr    IntrDate  Mult  \
# 0  93-HCONRES-1        1  hconres        0    93       0.0  1973-01-03   0.0
# 1  93-HCONRES-2        2  hconres        0    93       0.0  1973-01-03   0.0
# 2  93-HCONRES-3        3  hconres        0    93       0.0  1973-01-03   0.0
# 3  93-HCONRES-4        4  hconres        0    93       0.0  1973-01-03   0.0
# 4  93-HCONRES-5        5  hconres        0    93       0.0  1973-01-03   0.0
#
#    MultNo  PLaw  Private                                              Title  \
# 0     1.0     0        0  A concurrent resolution making the necessary a...
# 1     1.0     0        0  Concurrent resolution expressing the sense of ...
# 2     1.0     0        0  Concurrent resolution to establish a Joint Com...
# 3     1.0     0        0  Concurrent resolution expressing the sense of ...
# 4     1.0     0        0  Concurrent resolution expressing the sense of ...
#
# ...

# %%
bills80_92_cols = set(bills80_92.columns.tolist())
bills93_114_cols = set(bills93_114.columns.tolist())

# %%
bills93_114_cols - bills80_92_cols
# Out:
# {'ImpBill'}

# %%
bills80_92_cols - bills93_114_cols
# Out:
# {'Age',
#  'ByReq',
#  'ComMArr',
#  'Commem',
#  'DW2',
#  'LeadCham',
#  'LeadComm',
#  'LeadSubC',
#  'Month',
#  'ReferArr',
#  'Year',
#  'id',
#  'oldMajor',
#  'oldMinor'}

# %% [markdown]
# # 2. Presidential debates

# %% [markdown]
# links to debate transcripts from menu on left of webpage 'https://www.debates.org/index.php?page=debate-transcripts'
#
# scrape speeches with BeautifulSoup

# %%
url = 'https://www.debates.org/index.php?page=debate-transcripts'
header = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
r = requests.get(url) #, headers=header)

# %%
soup = BeautifulSoup(r.content, 'html.parser')

# %% [markdown]
# use Chrome and 'inspect' to see the name to give to soup.find

# %%
debates = soup.find("ul", {"class" : "arrow1"}).find_all("li")[9]

# %%
debate_links = debates.find_all('a', href=True)
debate_urls = [link.get('href') for link in debate_links]
debate_urls = debate_urls[:-1] # last link not a debate
debate_urls
# Out:
# ['https://www.debates.org/index.php?page=october-19-2016-debate-transcript',
#  'https://www.debates.org/index.php?page=october-9-2016-debate-transcript',
#  'https://www.debates.org/index.php?page=october-4-2016-debate-transcript',
#  'https://www.debates.org/index.php?page=september-26-2016-debate-transcript',
#  'https://www.debates.org/index.php?page=october-22-2012-the-third-obama-romney-presidential-debate',
#  'https://www.debates.org/index.php?page=october-16-2012-the-second-obama-romney-presidential-debate',
#  'https://www.debates.org/index.php?page=october-11-2012-the-biden-romney-vice-presidential-debate',
#  'https://www.debates.org/index.php?page=october-3-2012-debate-transcript',
#  'https://www.debates.org/index.php?page=2008-debate-transcript',
#  'https://www.debates.org/index.php?page=2008-debate-transcript-2',
#  'https://www.debates.org/index.php?page=october-7-2008-debate-transcrip',
#  'https://www.debates.org/index.php?page=october-15-2008-debate-transcript',
# ...

# %%
df_debates = pd.DataFrame(columns=['title', 'text'])

for i, debate_url in enumerate(debate_urls):
    r = requests.get(debate_url)
    soup = BeautifulSoup(r.content, 'html.parser')
    content = soup.find("div", {"id": "content-sm"})
    
    title = content.find('h1').getText()
    print(title)

    text = content.getText()
    
    df_debates.loc[i] = [title, text]
# Out:
# October 19, 2016 Debate Transcript
# October 9, 2016 Debate Transcript
# October 4, 2016 Debate Transcript
# September 26, 2016 Debate Transcript
# October 22, 2012 Debate Transcript
# October 16, 2012 Debate Transcript
# October 11, 2012 Debate Transcript
# October 3, 2012 Debate Transcript
# September 26, 2008 Debate Transcript
# October 2, 2008 Debate Transcript
# October 7, 2008 Debate Transcript
# October 15, 2008 Debate Transcript
# October 13, 2004 Debate Transcript
# October 8, 2004 Debate Transcript
# October 5, 2004 Transcript
# September 30. 2004 Debate Transcript
# October 3, 2000 Transcript
# October 5, 2000 Debate Transcript
# October 11, 2000 Debate Transcript
# October 17, 2000 Debate Transcript
# October 6, 1996 Debate Transcript
# October 9, 1996 Debate Transcript
# October 16, 1996 Debate Transcript
# October 11, 1992 First Half Debate Transcript
# October 11, 1992 Second Half Debate Transcript
# October 13, 1992 Debate Transcript
# ...

# %%
df_debates.head()
# Out:
#                                   title  \
# 0    October 19, 2016 Debate Transcript
# 1     October 9, 2016 Debate Transcript
# 2     October 4, 2016 Debate Transcript
# 3  September 26, 2016 Debate Transcript
# 4    October 22, 2012 Debate Transcript
#
#                                                 text
# 0  \nOctober 19, 2016 Debate Transcript\n\nPresid...
# 1  \nOctober 9, 2016 Debate Transcript\n\nPreside...
# 2  \nOctober 4, 2016 Debate Transcript\n\nVice Pr...
# 3  \nSeptember 26, 2016 Debate Transcript\n\nPres...
# 4  \nOctober 22, 2012 Debate Transcript\n\nPRESID...

# %%
df_debates.loc[0,'text']
# Out:
# '\nOctober 19, 2016 Debate Transcript\n\nPresidential Debate at the University of Nevada in Las VegasOctober 19, 2016PARTICIPANTS:Former Secretary of State Hillary Clinton (D) andBusinessman Donald Trump (R)MODERATOR:Chris Wallace (Fox News)WALLACE: Good evening from the Thomas and Mack Center at the University of Nevada, Las Vegas. I\'m Chris Wallace of Fox News, and I welcome you to the third and final of the 2016 presidential debates between Secretary of State Hillary Clinton and Donald J. Trump.This debate is sponsored by the Commission on Presidential Debates. The commission has designed the format: Six roughly 15-minute segments with two-minute answers to the first question, then open discussion for the rest of each segment. Both campaigns have agreed to those rules.For the record, I decided the topics and the questions in each topic. None of those questions has been shared with the commission or the two candidates. The audience here in the hall has promised to remain silent. N
# ...

# %%
df_debates.to_csv('presidential_debates.csv')

# %% [markdown]
# # 3. Presidential speeches

# %% [markdown]
# downloaded from http://www.thegrammarlab.com/?nor-portfolio=corpus-of-presidential-speeches-cops-and-a-clintontrump-corpus
#
# Example data:

# %%
path = Path('Corpus of Presential Speeches/')
folders = [Path(f.path) for f in os.scandir(path) if f.is_dir()]

# %%
file_list = []

for root, directories, filenames in os.walk(path):
    for filename in filenames:
        file_list.append(os.path.join(root, filename))

len(file_list)
# Out:
# 1080

# %%
f = open(file_list[0], "r")
f.readlines()
# Out:
# ['<title="Special Session Message to Congress">\n',
#  '<date="May 16, 1797">\n',
# ...

# %% [markdown]
# # 4. Congressional speeches

# %% [markdown]
# downloaded from https://data.stanford.edu/congress_text. code book at https://stacks.stanford.edu/file/druid:md374tz9962/codebook.pdf
#
# files are indexed by number from 43 to 111. example set of files with index 43:

# %%
path = Path('hein-bound-43/')

# %%
df_speaker_metadata = pd.read_csv(path / '043_SpeakerMap.txt', delimiter='|')
df_speaker_metadata.head()
# Out:
#    speakerid  speech_id  lastname firstname chamber state gender party  \
# 0   43044451  430000002    HAMLIN  HANNIBAL       S    ME      M     R
# 1   43049531  430000007   ANTHONY     HENRY       S    RI      M     R
# 2   43049531  430000008   ANTHONY     HENRY       S    RI      M     R
# 3   43047111  430000010  CONKLING    ROSCOE       S    NY      M     R
# 4   43044451  430000011    HAMLIN  HANNIBAL       S    ME      M     R
#
#    district nonvoting
# 0       NaN    voting
# 1       NaN    voting
# 2       NaN    voting
# 3       NaN    voting
# 4       NaN    voting

# %%
df_speech_metadata = pd.read_csv(path / 'descr_043.txt', delimiter='|')
df_speech_metadata.head()
# Out:
#    speech_id chamber      date  number_within_file             speaker  \
# 0  430000001       S  18730304                   1  The VICE-PRESIDENT
# 1  430000002       S  18730304                   2          Mr. HAMLIN
# 2  430000003       S  18730304                   3  The VICE-PRESIDENT
# 3  430000004       S  18730304                   4  The VICE-PRESIDENT
# 4  430000005       S  18730304                   5       The PRESIDENT
#
#   first_name last_name    state   gender  line_start  line_end          file  \
# 0    Unknown   Unknown  Unknown  Special          39        65  03041873.txt
# 1    Unknown    HAMLIN  Unknown        M          66        71  03041873.txt
# 2    Unknown   Unknown  Unknown  Special          72        73  03041873.txt
# 3    Unknown   Unknown  Unknown  Special         137       147  03041873.txt
# 4    Unknown   Unknown  Unknown  Special         148       158  03041873.txt
#
#    char_count  word_count
# 0         972         161
# ...

# %%
df_speeches = pd.read_csv(path / 'speeches_043.txt', encoding='cp1252')
df_speeches.head()
# Out:
#                                     speech_id|speech
# 0  430000001|The Secretary will read the names of...
# 1  430000002|said: Mr. President. owing to some i...
# 2  430000003|The question is on the motion of the...
# 3  430000004|The order of proceedings will now be...
# 4  430000005|of the United States. the PRESIDENTE...

# %%
df_speeches_split = df_speeches['speech_id|speech'].str.split('|', n=1, expand=True)
df_speeches_split.head()
# Out:
#            0                                                  1
# 0  430000001  The Secretary will read the names of the newly...
# 1  430000002  said: Mr. President. owing to some inadvertenc...
# 2  430000003  The question is on the motion of the Senator f...
# 3  430000004  The order of proceedings will now be formed. f...
# 4  430000005  of the United States. the PRESIDENTELEcT. The ...
